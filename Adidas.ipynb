# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("Adidas.xlsx")

# %%
df
# Out:
#          Retailer  RetailerID InvoiceDate     Region          State  \
# 0     Foot Locker     1185732  2020-02-03  Northeast       New York
# 1     Foot Locker     1185732  2020-02-04  Northeast       New York
# 2     Foot Locker     1185732  2020-02-05  Northeast       New York
# 3     Foot Locker     1185732  2020-02-06  Northeast       New York
# 4     Foot Locker     1185732  2020-02-07  Northeast       New York
# ...           ...         ...         ...        ...            ...
# 9643  Foot Locker     1185732  2021-01-24  Northeast  New Hampshire
# 9644  Foot Locker     1185732  2021-01-24  Northeast  New Hampshire
# 9645  Foot Locker     1185732  2021-02-22  Northeast  New Hampshire
# 9646  Foot Locker     1185732  2021-02-22  Northeast  New Hampshire
# 9647  Foot Locker     1185732  2021-02-22  Northeast  New Hampshire
#
#             City                    Product  PriceperUnit  UnitsSold  \
# 0       New York  Women's Athletic Footwear          45.0        825
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Retailer           0
# RetailerID         0
# InvoiceDate        0
# Region             0
# State              0
# City               0
# Product            0
# PriceperUnit       0
# UnitsSold          0
# TotalSales         0
# OperatingProfit    0
# OperatingMargin    0
# SalesMethod        0
# dtype: int64

# %%
df.dtypes
# Out:
# Retailer                   object
# RetailerID                  int64
# InvoiceDate        datetime64[ns]
# Region                     object
# State                      object
# City                       object
# Product                    object
# PriceperUnit              float64
# UnitsSold                   int64
# TotalSales                float64
# OperatingProfit           float64
# OperatingMargin           float64
# SalesMethod                object
# dtype: object

# %%
df.head()
# Out:
#       Retailer  RetailerID InvoiceDate     Region     State      City  \
# 0  Foot Locker     1185732  2020-02-03  Northeast  New York  New York
# 1  Foot Locker     1185732  2020-02-04  Northeast  New York  New York
# 2  Foot Locker     1185732  2020-02-05  Northeast  New York  New York
# 3  Foot Locker     1185732  2020-02-06  Northeast  New York  New York
# 4  Foot Locker     1185732  2020-02-07  Northeast  New York  New York
#
#                      Product  PriceperUnit  UnitsSold  TotalSales  \
# 0  Women's Athletic Footwear          45.0        825    371250.0
# 1              Men's Apparel          60.0        825    495000.0
# 2            Women's Apparel          50.0        950    475000.0
# 3      Men's Street Footwear          60.0       1220    732000.0
# 4    Men's Athletic Footwear          55.0        925    508750.0
#
#    OperatingProfit  OperatingMargin SalesMethod
# 0         129937.5             0.35      Outlet
# 1         148500.0             0.30      Outlet
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
df['PriceperUnit']
# Out:
# 0        45.0
# 1        60.0
# 2        50.0
# 3        60.0
# 4        55.0
# 5        50.0
# 6        50.0
# 7        50.0
# 8        40.0
# 9        45.0
# 10       60.0
# 11       50.0
# 12       50.0
# 13       50.0
# 14       40.0
# 15       45.0
# 16       60.0
# 17       50.0
# 18       50.0
# 19       50.0
# 20       40.0
# 21       45.0
# 22       60.0
# 23       50.0
# 24       50.0
# 25       50.0
# 26       40.0
# 27       50.0
# 28       60.0
# 29       65.0
# 30       60.0
# 31       55.0
# 32       50.0
# 33       50.0
# 34       60.0
# 35       65.0
# 36       60.0
# 37       55.0
# 38       50.0
# 39       50.0
# 40       60.0
# 41       65.0
# 42       60.0
# 43       55.0
# 44       50.0
# 45       50.0
# 46       60.0
# 47       65.0
# 48       60.0
# 49       55.0
# 50       50.0
# 51       50.0
# 52       60.0
# 53       65.0
# 54       65.0
# 55       70.0
# 56       65.0
# 57       55.0
# 58       55.0
# 59       55.0
# 60       65.0
# 61       70.0
# ...

# %%
df['PriceperUnit'] = df['PriceperUnit'].astype(int)

# %%
df.head()
# Out:
#       Retailer  RetailerID InvoiceDate     Region     State      City  \
# 0  Foot Locker     1185732  2020-02-03  Northeast  New York  New York
# 1  Foot Locker     1185732  2020-02-04  Northeast  New York  New York
# 2  Foot Locker     1185732  2020-02-05  Northeast  New York  New York
# 3  Foot Locker     1185732  2020-02-06  Northeast  New York  New York
# 4  Foot Locker     1185732  2020-02-07  Northeast  New York  New York
#
#                      Product  PriceperUnit  UnitsSold  TotalSales  \
# 0  Women's Athletic Footwear            45        825    371250.0
# 1              Men's Apparel            60        825    495000.0
# 2            Women's Apparel            50        950    475000.0
# 3      Men's Street Footwear            60       1220    732000.0
# 4    Men's Athletic Footwear            55        925    508750.0
#
#    OperatingProfit  OperatingMargin SalesMethod
# 0         129937.5             0.35      Outlet
# 1         148500.0             0.30      Outlet
# ...

# %%
df['TotalSales']
# Out:
# 0       371250.0
# 1       495000.0
# 2       475000.0
# 3       732000.0
# 4       508750.0
# 5       450000.0
# 6       382500.0
# 7       500000.0
# 8       400000.0
# 9       382500.0
# 10      540000.0
# 11      500000.0
# 12      625000.0
# 13      450000.0
# 14      380000.0
# 15      371250.0
# 16      540000.0
# 17      500000.0
# 18      610000.0
# 19      462500.0
# 20      380000.0
# 21      360000.0
# 22      510000.0
# 23      475000.0
# 24      600000.0
# 25      450000.0
# 26      360000.0
# 27      425000.0
# 28      525000.0
# 29      650000.0
# 30      750000.0
# 31      550000.0
# 32      462500.0
# 33      450000.0
# 34      540000.0
# 35      682500.0
# 36      765000.0
# 37      563750.0
# 38      475000.0
# 39      450000.0
# 40      555000.0
# 41      715000.0
# 42      750000.0
# 43      563750.0
# 44      475000.0
# 45      462500.0
# 46      540000.0
# 47      698750.0
# 48      720000.0
# 49      550000.0
# 50      462500.0
# 51      450000.0
# ...

# %%
df['TotalSales'] = df['TotalSales'].astype(int)

# %%
df['OperatingMargin']
# Out:
# 0       0.35
# 1       0.30
# 2       0.25
# 3       0.50
# 4       0.30
# 5       0.35
# 6       0.50
# 7       0.30
# 8       0.35
# 9       0.35
# 10      0.30
# 11      0.25
# 12      0.50
# 13      0.30
# 14      0.35
# 15      0.35
# 16      0.30
# 17      0.25
# 18      0.50
# 19      0.30
# 20      0.35
# 21      0.35
# 22      0.30
# 23      0.25
# 24      0.50
# 25      0.30
# 26      0.35
# 27      0.35
# 28      0.30
# 29      0.25
# 30      0.50
# 31      0.30
# 32      0.35
# 33      0.35
# 34      0.30
# 35      0.25
# 36      0.50
# 37      0.30
# 38      0.35
# 39      0.35
# 40      0.30
# 41      0.25
# 42      0.50
# 43      0.30
# 44      0.35
# 45      0.35
# 46      0.30
# 47      0.25
# 48      0.50
# 49      0.30
# 50      0.35
# 51      0.35
# 52      0.30
# 53      0.25
# 54      0.30
# 55      0.25
# 56      0.50
# 57      0.30
# 58      0.35
# 59      0.35
# 60      0.30
# 61      0.25
# 62      0.50
# 63      0.30
# 64      0.35
# 65      0.35
# ...

# %%
# df2 = df.copy()

# %%
#df['OperatingMargin'] = df['OperatingMargin'].astype(int)
df['OperatingMargin'] = (df['OperatingMargin'] * 100).astype(np.int64)

# %%
df.dtypes
# Out:
# Retailer                   object
# RetailerID                  int64
# InvoiceDate        datetime64[ns]
# Region                     object
# State                      object
# City                       object
# Product                    object
# PriceperUnit                int64
# UnitsSold                   int64
# TotalSales                  int64
# OperatingProfit           float64
# OperatingMargin             int64
# SalesMethod                object
# dtype: object

# %%
df.shape
# Out:
# (9648, 13)

# %%
df['Retailer'].unique()
# Out:
# array(['Foot Locker', 'Walmart', 'Sports Direct', 'West Gear', "Kohl's",
#        'Amazon'], dtype=object)

# %%
df['Retailer'].value_counts()
# Out:
# Retailer
# Foot Locker      2637
# West Gear        2374
# Sports Direct    2032
# Kohl's           1030
# Amazon            949
# Walmart           626
# Name: count, dtype: int64

# %%
df['Region'].unique()
# Out:
# array(['Northeast', 'South', 'West', 'Midwest', 'Southeast'], dtype=object)

# %%
df['Region'].value_counts()
# Out:
# Region
# West         2448
# Northeast    2376
# Midwest      1872
# South        1728
# Southeast    1224
# Name: count, dtype: int64

# %%
df['State'].unique()
# Out:
# array(['New York', 'Texas', 'California', 'Illinois', 'Pennsylvania',
#        'Nevada', 'Colorado', 'Washington', 'Florida', 'Minnesota',
#        'Montana', 'Tennessee', 'Nebraska', 'Alabama', 'Maine', 'Alaska',
#        'Hawaii', 'Wyoming', 'Virginia', 'Michigan', 'Missouri', 'Utah',
#        'Oregon', 'Louisiana', 'Idaho', 'Arizona', 'New Mexico', 'Georgia',
#        'South Carolina', 'North Carolina', 'Ohio', 'Kentucky',
#        'Mississippi', 'Arkansas', 'Oklahoma', 'Kansas', 'South Dakota',
#        'North Dakota', 'Iowa', 'Wisconsin', 'Indiana', 'West Virginia',
#        'Maryland', 'Delaware', 'New Jersey', 'Connecticut',
#        'Rhode Island', 'Massachusetts', 'Vermont', 'New Hampshire'],
#       dtype=object)

# %%
df['State'].value_counts()
# Out:
# State
# Texas             432
# California        432
# New York          360
# Florida           360
# Nevada            216
# Pennsylvania      216
# Alabama           216
# Tennessee         216
# Arkansas          216
# Mississippi       216
# New Mexico        216
# Georgia           216
# Arizona           216
# Idaho             216
# Oregon            216
# Louisiana         216
# Utah              216
# Virginia          216
# New Hampshire     216
# Vermont           216
# Connecticut       216
# Rhode Island      216
# Massachusetts     216
# Oklahoma          216
# Wyoming           144
# Hawaii            144
# Colorado          144
# Illinois          144
# Alaska            144
# Maine             144
# Nebraska          144
# Montana           144
# Washington        144
# Minnesota         144
# Ohio              144
# Kentucky          144
# South Carolina    144
# North Carolina    144
# Missouri          144
# Michigan          144
# South Dakota      144
# ...

# %%
df['City'].unique()
# Out:
# array(['New York', 'Houston', 'San Francisco', 'Los Angeles', 'Chicago',
#        'Dallas', 'Philadelphia', 'Las Vegas', 'Denver', 'Seattle',
#        'Miami', 'Minneapolis', 'Billings', 'Knoxville', 'Omaha',
#        'Birmingham', 'Portland', 'Anchorage', 'Honolulu', 'Orlando',
#        'Albany', 'Cheyenne', 'Richmond', 'Detroit', 'St. Louis',
#        'Salt Lake City', 'New Orleans', 'Boise', 'Phoenix', 'Albuquerque',
#        'Atlanta', 'Charleston', 'Charlotte', 'Columbus', 'Louisville',
#        'Jackson', 'Little Rock', 'Oklahoma City', 'Wichita',
#        'Sioux Falls', 'Fargo', 'Des Moines', 'Milwaukee', 'Indianapolis',
#        'Baltimore', 'Wilmington', 'Newark', 'Hartford', 'Providence',
#        'Boston', 'Burlington', 'Manchester'], dtype=object)

# %%
df['City'].value_counts()
# Out:
# City
# Portland          360
# Charleston        288
# San Francisco     216
# New York          216
# Los Angeles       216
# Dallas            216
# Las Vegas         216
# Philadelphia      216
# Birmingham        216
# Orlando           216
# Knoxville         216
# Jackson           216
# Salt Lake City    216
# Phoenix           216
# Albuquerque       216
# Atlanta           216
# Boise             216
# New Orleans       216
# Richmond          216
# Houston           216
# Manchester        216
# Hartford          216
# Boston            216
# Providence        216
# Oklahoma City     216
# Burlington        216
# Little Rock       216
# Honolulu          144
# Chicago           144
# Anchorage         144
# Billings          144
# Omaha             144
# Denver            144
# Seattle           144
# Miami             144
# Minneapolis       144
# Louisville        144
# Columbus          144
# Charlotte         144
# St. Louis         144
# Detroit           144
# ...

# %%
df['Product'].unique()
# Out:
# array(["Women's Athletic Footwear", "Men's Apparel", "Women's Apparel",
#        "Men's Street Footwear", "Men's Athletic Footwear",
#        "Women's Street Footwear"], dtype=object)

# %%
df['Product'].value_counts()
# Out:
# Product
# Men's Athletic Footwear      1610
# Men's Street Footwear        1610
# Women's Apparel              1608
# Women's Street Footwear      1608
# Men's Apparel                1606
# Women's Athletic Footwear    1606
# Name: count, dtype: int64

# %%
pip install streamlit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df.columns
# Out:
# Index(['Retailer', 'RetailerID', 'InvoiceDate', 'Region', 'State', 'City',
#        'Product', 'PriceperUnit', 'UnitsSold', 'TotalSales', 'OperatingProfit',
#        'OperatingMargin', 'SalesMethod'],
#       dtype='object')

# %%
# Specify the new column order
new_column_order = ['RetailerID', 'Retailer', 'InvoiceDate', 'Region', 'State', 'City',
       'Product', 'PriceperUnit', 'UnitsSold', 'TotalSales', 'OperatingProfit',
       'OperatingMargin', 'SalesMethod']

# Reorder the DataFrame columns
df = df[new_column_order]

# Display the DataFrame with reordered columns
print(df)
# Out:
#       RetailerID       Retailer InvoiceDate     Region           State  \
# 0        1185732    Foot Locker  2020-02-03  Northeast        New York
# 1        1185732    Foot Locker  2020-02-04  Northeast        New York
# 2        1185732    Foot Locker  2020-02-05  Northeast        New York
# 3        1185732    Foot Locker  2020-02-06  Northeast        New York
# 4        1185732    Foot Locker  2020-02-07  Northeast        New York
# 5        1185732    Foot Locker  2020-02-08  Northeast        New York
# 6        1185732    Foot Locker  2020-01-01  Northeast        New York
# 7        1185732    Foot Locker  2020-01-02  Northeast        New York
# 8        1185732    Foot Locker  2020-01-03  Northeast        New York
# 9        1185732    Foot Locker  2020-01-04  Northeast        New York
# 10       1185732    Foot Locker  2020-01-05  Northeast        New York
# 11       1185732    Foot Locker  2020-01-06  Northeast        New York
# ...

# %%
df.head()
# Out:
#    RetailerID     Retailer InvoiceDate     Region     State      City  \
# 0     1185732  Foot Locker  2020-02-03  Northeast  New York  New York
# 1     1185732  Foot Locker  2020-02-04  Northeast  New York  New York
# 2     1185732  Foot Locker  2020-02-05  Northeast  New York  New York
# 3     1185732  Foot Locker  2020-02-06  Northeast  New York  New York
# 4     1185732  Foot Locker  2020-02-07  Northeast  New York  New York
#
#                      Product  PriceperUnit  UnitsSold  TotalSales  \
# 0  Women's Athletic Footwear            45        825      371250
# 1              Men's Apparel            60        825      495000
# 2            Women's Apparel            50        950      475000
# 3      Men's Street Footwear            60       1220      732000
# 4    Men's Athletic Footwear            55        925      508750
#
#    OperatingProfit  OperatingMargin SalesMethod
# 0         129937.5               35      Outlet
# 1         148500.0               30      Outlet
# ...

# %%
df['TotalSales']
# Out:
# 0       371250
# 1       495000
# 2       475000
# 3       732000
# 4       508750
# 5       450000
# 6       382500
# 7       500000
# 8       400000
# 9       382500
# 10      540000
# 11      500000
# 12      625000
# 13      450000
# 14      380000
# 15      371250
# 16      540000
# 17      500000
# 18      610000
# 19      462500
# 20      380000
# 21      360000
# 22      510000
# 23      475000
# 24      600000
# 25      450000
# 26      360000
# 27      425000
# 28      525000
# 29      650000
# 30      750000
# 31      550000
# 32      462500
# 33      450000
# 34      540000
# 35      682500
# 36      765000
# 37      563750
# 38      475000
# 39      450000
# 40      555000
# 41      715000
# 42      750000
# 43      563750
# 44      475000
# 45      462500
# 46      540000
# 47      698750
# 48      720000
# 49      550000
# 50      462500
# 51      450000
# 52      540000
# 53      650000
# 54      568750
# 55      700000
# 56      747500
# 57      536250
# ...

# %%
#df1 = df.copy()

# %%
df['TotalSales'] = df['TotalSales'] / 10

# %%
df.head()
# Out:
#    RetailerID     Retailer InvoiceDate     Region     State      City  \
# 0     1185732  Foot Locker  2020-02-03  Northeast  New York  New York
# 1     1185732  Foot Locker  2020-02-04  Northeast  New York  New York
# 2     1185732  Foot Locker  2020-02-05  Northeast  New York  New York
# 3     1185732  Foot Locker  2020-02-06  Northeast  New York  New York
# 4     1185732  Foot Locker  2020-02-07  Northeast  New York  New York
#
#                      Product  PriceperUnit  UnitsSold  TotalSales  \
# 0  Women's Athletic Footwear            45        825     37125.0
# 1              Men's Apparel            60        825     49500.0
# 2            Women's Apparel            50        950     47500.0
# 3      Men's Street Footwear            60       1220     73200.0
# 4    Men's Athletic Footwear            55        925     50875.0
#
#    OperatingProfit  OperatingMargin SalesMethod
# 0         129937.5               35      Outlet
# 1         148500.0               30      Outlet
# ...

# %%
df.head()
# Out:
#    RetailerID     Retailer InvoiceDate     Region     State      City  \
# 0     1185732  Foot Locker  2020-02-03  Northeast  New York  New York
# 1     1185732  Foot Locker  2020-02-04  Northeast  New York  New York
# 2     1185732  Foot Locker  2020-02-05  Northeast  New York  New York
# 3     1185732  Foot Locker  2020-02-06  Northeast  New York  New York
# 4     1185732  Foot Locker  2020-02-07  Northeast  New York  New York
#
#                      Product  PriceperUnit  UnitsSold  TotalSales  \
# 0  Women's Athletic Footwear            45        825     37125.0
# 1              Men's Apparel            60        825     49500.0
# 2            Women's Apparel            50        950     47500.0
# 3      Men's Street Footwear            60       1220     73200.0
# 4    Men's Athletic Footwear            55        925     50875.0
#
#    OperatingProfit  OperatingMargin SalesMethod
# 0         129937.5               35      Outlet
# 1         148500.0               30      Outlet
# ...

# %%
df['TotalSales']
# Out:
# 0       37125.0
# 1       49500.0
# 2       47500.0
# 3       73200.0
# 4       50875.0
# 5       45000.0
# 6       38250.0
# 7       50000.0
# 8       40000.0
# 9       38250.0
# 10      54000.0
# 11      50000.0
# 12      62500.0
# 13      45000.0
# 14      38000.0
# 15      37125.0
# 16      54000.0
# 17      50000.0
# 18      61000.0
# 19      46250.0
# 20      38000.0
# 21      36000.0
# 22      51000.0
# 23      47500.0
# 24      60000.0
# 25      45000.0
# 26      36000.0
# 27      42500.0
# 28      52500.0
# 29      65000.0
# 30      75000.0
# 31      55000.0
# 32      46250.0
# 33      45000.0
# 34      54000.0
# 35      68250.0
# 36      76500.0
# 37      56375.0
# 38      47500.0
# 39      45000.0
# 40      55500.0
# 41      71500.0
# 42      75000.0
# 43      56375.0
# 44      47500.0
# 45      46250.0
# 46      54000.0
# 47      69875.0
# 48      72000.0
# 49      55000.0
# 50      46250.0
# 51      45000.0
# 52      54000.0
# 53      65000.0
# 54      56875.0
# ...

# %%
#df2 = df1.copy()

# %%
df['TotalSales'] = df['TotalSales'].astype(int)

# %%
df.tail()
# Out:
#       RetailerID     Retailer InvoiceDate     Region          State  \
# 9643     1185732  Foot Locker  2021-01-24  Northeast  New Hampshire
# 9644     1185732  Foot Locker  2021-01-24  Northeast  New Hampshire
# 9645     1185732  Foot Locker  2021-02-22  Northeast  New Hampshire
# 9646     1185732  Foot Locker  2021-02-22  Northeast  New Hampshire
# 9647     1185732  Foot Locker  2021-02-22  Northeast  New Hampshire
#
#             City                  Product  PriceperUnit  UnitsSold  \
# 9643  Manchester            Men's Apparel            50         64
# 9644  Manchester          Women's Apparel            41        105
# 9645  Manchester    Men's Street Footwear            41        184
# 9646  Manchester  Men's Athletic Footwear            42         70
# 9647  Manchester  Women's Street Footwear            29         83
#
#       TotalSales  OperatingProfit  OperatingMargin SalesMethod
# 9643         320           896.00               28      Outlet
# ...

# %%
#df = df2.copy()

# %%
df.head()
# Out:
#    RetailerID     Retailer InvoiceDate     Region     State      City  \
# 0     1185732  Foot Locker  2020-02-03  Northeast  New York  New York
# 1     1185732  Foot Locker  2020-02-04  Northeast  New York  New York
# 2     1185732  Foot Locker  2020-02-05  Northeast  New York  New York
# 3     1185732  Foot Locker  2020-02-06  Northeast  New York  New York
# 4     1185732  Foot Locker  2020-02-07  Northeast  New York  New York
#
#                      Product  PriceperUnit  UnitsSold  TotalSales  \
# 0  Women's Athletic Footwear            45        825       37125
# 1              Men's Apparel            60        825       49500
# 2            Women's Apparel            50        950       47500
# 3      Men's Street Footwear            60       1220       73200
# 4    Men's Athletic Footwear            55        925       50875
#
#    OperatingProfit  OperatingMargin SalesMethod
# 0         129937.5               35      Outlet
# 1         148500.0               30      Outlet
# ...

# %%
df.dtypes
# Out:
# RetailerID                  int64
# Retailer                   object
# InvoiceDate        datetime64[ns]
# Region                     object
# State                      object
# City                       object
# Product                    object
# PriceperUnit                int64
# UnitsSold                   int64
# TotalSales                  int64
# OperatingProfit           float64
# OperatingMargin             int64
# SalesMethod                object
# dtype: object

# %%
df['SalesMethod'].unique()
# Out:
# array(['Outlet', 'In-store', 'Online'], dtype=object)

# %%
# Subtracting 'OperatingProfit' from 'TotalSales' to get 'OperatingExpenses'
df['OperatingExpenses'] = df['OperatingProfit'] - df['TotalSales']

# %%
df.head()
# Out:
#    RetailerID     Retailer InvoiceDate     Region     State      City  \
# 0     1185732  Foot Locker  2020-02-03  Northeast  New York  New York
# 1     1185732  Foot Locker  2020-02-04  Northeast  New York  New York
# 2     1185732  Foot Locker  2020-02-05  Northeast  New York  New York
# 3     1185732  Foot Locker  2020-02-06  Northeast  New York  New York
# 4     1185732  Foot Locker  2020-02-07  Northeast  New York  New York
#
#                      Product  PriceperUnit  UnitsSold  TotalSales  \
# 0  Women's Athletic Footwear            45        825       37125
# 1              Men's Apparel            60        825       49500
# 2            Women's Apparel            50        950       47500
# 3      Men's Street Footwear            60       1220       73200
# 4    Men's Athletic Footwear            55        925       50875
#
#    OperatingProfit  OperatingMargin SalesMethod  OperatingExpenses
# 0         129937.5               35      Outlet            92812.5
# ...

# %%
average_price = int(df["PriceperUnit"].mean()*100)

# %%
average_price
# Out:
# 4518

# %%
df['State'].unique()
# Out:
# array(['New York', 'Texas', 'California', 'Illinois', 'Pennsylvania',
#        'Nevada', 'Colorado', 'Washington', 'Florida', 'Minnesota',
#        'Montana', 'Tennessee', 'Nebraska', 'Alabama', 'Maine', 'Alaska',
#        'Hawaii', 'Wyoming', 'Virginia', 'Michigan', 'Missouri', 'Utah',
#        'Oregon', 'Louisiana', 'Idaho', 'Arizona', 'New Mexico', 'Georgia',
#        'South Carolina', 'North Carolina', 'Ohio', 'Kentucky',
#        'Mississippi', 'Arkansas', 'Oklahoma', 'Kansas', 'South Dakota',
#        'North Dakota', 'Iowa', 'Wisconsin', 'Indiana', 'West Virginia',
#        'Maryland', 'Delaware', 'New Jersey', 'Connecticut',
#        'Rhode Island', 'Massachusetts', 'Vermont', 'New Hampshire'],
#       dtype=object)

# %%
# Assuming df is your DataFrame
df.to_csv('Adidas.csv', index=False)
